# %% [markdown]
# # header 1

# %% [markdown]
# ## header 2

# %% [markdown]
# ### header 3

# %% [markdown]
# #### header 4

# %% [markdown]
# # <center> heaader 1

# %% [markdown]
# - bullet
# - bullet 2

# %% [markdown]
# ![Gemini_Generated_Image_w0novhw0novhw0no.png](attachment:28691f6e-519b-49e2-a38f-35a6ae0079f9.png)

# %% [markdown]
# this ia a markdown demo

# %%
# comment
100+200
# Out:
# 300

# %%
3*3
# Out:
# 9

# %%
5/2
# Out:
# 2.5

# %%
1+2
# Out:
# 3
